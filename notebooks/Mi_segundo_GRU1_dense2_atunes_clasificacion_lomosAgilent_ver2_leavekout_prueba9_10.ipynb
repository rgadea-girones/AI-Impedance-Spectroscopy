# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import LSTM,Bidirectional,GRU
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.utils import to_categorical
import datetime
import io
import itertools
# import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

from sklearn.model_selection import KFold
from sklearn.metrics import classification_report

import sys
import os
# Obtener la ruta del directorio actual
os.chdir('..')
current_dir = os.getcwd()
print(current_dir)

# Construir la ruta relativa al directorio que quieres agregar
relative_dir = os.path.join(current_dir, 'mis_pkgs/')

# Agregar la ruta relativa al sys.path
sys.path.insert(0, relative_dir)

from MIOPATIA_db import DB_management as db
# Out:
# 2024-07-08 14:23:14.355875: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-08 14:23:14.355935: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-08 14:23:14.356801: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-08 14:23:14.363049: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-08 14:23:15.104026: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/rgadea/.local/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/rgadea/nuevas_investigaciones_alimentos_2024

# %%
numero_muestras=201
numero_clases=2
entrada=[9,10]
numero_entradas =2
numero_epochs=20000

# %% [markdown]
# Voy a quedarme con los 50 atunes P1 para obtener conjunto de training y validacion

# %%
filename = "COPIA_PANDAS/medidas_agilent_2023_y_2024_201_puntos_clasificados.hdf"
with pd.HDFStore(filename,complib="zlib",complevel=4) as hdf_db:
    pre_p_e1  = hdf_db.get('data/pollos_estado')
    pre_p_e1 = pre_p_e1.loc[pre_p_e1['Pollo'] != 0]
    # p_e =pre_p_e1.drop_duplicates(subset = ['Pollo', 'Medida'],  keep = 'last').reset_index(drop = True)
    t    = hdf_db.get('data/tabla')
    X_train=np.zeros((pre_p_e1.shape[0],numero_muestras,numero_entradas))
    y_train=np.zeros((pre_p_e1.shape[0],1))
    x=0
    for index, row in pre_p_e1.iterrows():   # El primer registro no se toma en cuenta porque es basura
        Primero = int(row['Primero'])
        Ultimo  = int(row['Ultimo'])
        estado  = int(row['Estado'])
        #print(Primero)
        #print(Ultimo)
        #print(estado)
        if numero_clases==2:
            if estado == 0 or estado== 1:
                target = 0
            else:
                target = 1
        else:
            target=estado
        pepito=np.array(t.iloc[Primero:Ultimo+1])
        # #print(pepito.shape)
        X_train[x]=pepito[:,entrada]
        #print(X_train[x][0:4,:])       
        y_train[x]=target
        y_train_to_categorical = to_categorical(y_train)
        x=x+1



X_train_filtrado = X_train
#y_train_filtrado = y_train
y_train_filtrado = y_train_to_categorical


scaler = MinMaxScaler(feature_range=(0, 1))
#scaler = StandardScaler()



#data1=np.concatenate((X_train_filtrado,X_test_filtrado1),axis=0) 

data_2d = X_train_filtrado.reshape(-1, X_train_filtrado.shape[-1])
normalized_data_2d = scaler.fit_transform(data_2d)



X_train_Normalizado=normalized_data_2d.reshape(X_train_filtrado.shape)
y_train_Normalizado=y_train_filtrado # los valores ya estaban normalizados
print(data_2d.shape)
print(X_train_Normalizado.shape)
print(y_train_Normalizado.shape)

inputs=X_train_Normalizado.reshape(X_train_Normalizado.shape[0],-1)
targets=y_train_Normalizado

print(inputs.shape)
print(targets.shape)
# Out:
# (38994, 2)
# (194, 201, 2)
# (194, 2)
# (194, 402)
# (194, 2)

# %% [markdown]
# Vamos a hacer los conjuntos de entrenamiento validacion y test

# %%
factor_aprendizaje=0.001
dimension_LSTM=200
dimension_dense1=50
dimension_dense2=20
algoritmo='rmsprop'
supermax=8*4
lossfunction='categorical_crossentropy'
def create_model():

    model = Sequential()
    model.add(Bidirectional(GRU(dimension_LSTM, return_sequences=True,recurrent_regularizer='L2',input_shape=(numero_muestras, numero_entradas))))
    model.add(Flatten())  
    #model.add(GRU(50, return_sequences=True))
    #model.add(GRU(50, return_sequences=False, recurrent_regularizer='L2'))
    model.add(Dense(dimension_dense1, activation='tanh', activity_regularizer='L2'))
    model.add(Dense(dimension_dense2, activation='tanh'))
    model.add(Dense(numero_clases, activation='softmax'))
    model.compile(loss=lossfunction, optimizer=algoritmo, metrics=['accuracy',
                              tf.keras.metrics.Recall(class_id=0),
                              tf.keras.metrics.Recall(class_id=1) #,
                              #tfa.metrics.F1Score(num_classes=numero_clases,average='macro', threshold=0.5)
                              ])
    model.optimizer.lr=(factor_aprendizaje)
    return model

# %%
experimento="LOMOS_Agilent_5clases_GRU1_{}_dense1_{}_dense2_{}_loss_{}_lr_{}_algoritmo_{}".format(dimension_LSTM,dimension_dense1,dimension_dense2,lossfunction,factor_aprendizaje,algoritmo)
logdir="./logs/defs/leavekout/{}_{}".format(experimento,datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback=tf.keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq=1)
file_writer_cm = tf.summary.create_file_writer(logdir + '/cm')
# Out:
# 2024-07-08 14:23:18.144468: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-08 14:23:18.171734: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-08 14:23:18.171786: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-08 14:23:18.173778: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-08 14:23:18.173850: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-08 14:23:18.173885: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-08 14:23:18.289841: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-08 14:23:18.289930: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-08 14:23:18.289939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-07-08 14:23:18.289982: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-08 14:23:18.290003: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6692 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
if numero_clases==2:
    class_names=['Buenos', 'Malos']
else:
    class_names=['A', 'B+', 'B', 'B-','C']

# %%
lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.95,
    patience=1000,
    min_lr=0.0001
)
early_stop=tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', min_delta=0, patience=2000, verbose=2, mode='auto', baseline=None, restore_best_weights=True)
# Define the K-fold Cross Validator
kfold = KFold(n_splits=10, shuffle=True)
# Define per-fold score containers
acc_per_fold = []
loss_per_fold = []
sensibilidad_YAKE_per_fold=[]
sensibilidad_no_YAKE_per_fold=[]
# K-fold Cross Validation model evaluation
fold_no = 1
for train, test in kfold.split(inputs, targets):
    model=create_model()
     # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')
    inputs_good=inputs.reshape(X_train_filtrado.shape)
    # Fit data to model
    history = model.fit(inputs_good[train], targets[train],
              batch_size=20,
              epochs=numero_epochs,
              callbacks=[early_stop,lr_callback, tensorboard_callback],
              validation_data=(inputs_good[test],targets[test])
              )
    if numero_clases==2:
        target_names = ['Buenos', 'Malos']
    else:   
        target_names = ['A', 'B+', 'B', 'B-','C']
    y_pred = model.predict(inputs_good[test])
    y_pred2=np.argmax(y_pred,axis=1)
    y_test_def2=np.argmax(targets[test],axis=1)
    print(classification_report(y_test_def2, y_pred2, target_names=target_names, digits=4))
    # Generate generalization metrics
    scores = model.evaluate(inputs_good[test], targets[test], verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    print(scores[2])
    print(scores[3])
   # print(scores[4])
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])
    sensibilidad_YAKE_per_fold.append(scores[2] * 100)
    sensibilidad_no_YAKE_per_fold.append(scores[3] * 100)
    # Increase fold number
    fold_no = fold_no + 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/20000
# 2024-07-08 14:23:18.942927: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024
- val_accuracy: 0.6500 - val_recall: 1.0000 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 194/20000
# 9/9 [==============================] - 1s 113ms/step - loss: 0.6847 - accuracy: 0.5172 - recall: 0.8021 - recall_1: 0.1667 - val_loss: 0.6830 - val_accuracy: 0.6500 - val_recall: 1.0000 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 195/20000
# ...
#    1870                         "val_" + name: val for name, val in val_logs.items()
#    1871                     }
#    1872                     epoch_logs.update(val_logs)
#    1873
# -> 1874                 callbacks.on_epoch_end(epoch, epoch_logs)
#    1875                 training_logs = epoch_logs
#    1876                 if self.stop_training:
#    1877                     break
#
# ~/.local/lib/python3.10/site-packages/keras/src/callbacks.py in ?(self, epoch, logs)
#     449               keys are prefixed with `val_`.
#     450         """
#     451         logs = self._process_logs(logs)
#     452         for callback in self.callbacks:
# --> 453             callback.on_epoch_end(epoch, logs)
#
# ~/.local/lib/python3.10/site-packages/keras/src/callbacks.py in ?(self, epoch, logs)
#    2847         """Runs metrics and histogram summaries at epoch end."""
#    2848         self._log_epoch_metrics(epoch, logs)
#    2849
#    2850         if self.histogram_freq and epoch % self.histogram_freq == 0:
# -> 2851             self._log_weights(epoch)
#    2852
#    2853         if self.embeddings_freq and epoch % self.embeddings_freq == 0:
#    2854             self._log_embeddings(epoch)
#
# ~/.local/lib/python3.10/site-packages/keras/src/callbacks.py in ?(self, epoch)
#    2927                     for weight in layer.weights:
#    2928                         weight_name = weight.name.replace(":", "_")
#    2929                         # Add a suffix to prevent summary tag name collision.
#    2930                         histogram_weight_name = weight_name + "/histogram"
# -> 2931                         tf.summary.histogram(
#    2932                             histogram_weight_name, weight, step=epoch
#    2933                         )
#    2934                         if self.write_images:
#
# ~/.local/lib/python3.10/site-packages/tensorboard/plugins/histogram/summary_v2.py in ?(name, data, step, buckets, description)
#     192         @lazy_tensor_creator.LazyTensorCreator
#     193         def lazy_tensor():
#     194             return _buckets(data, buckets)
#     195
# --> 196         return tf.summary.write(
#     197             tag=tag,
#     198             tensor=lazy_tensor,
#     199             step=step,
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/summary_ops_v2.py in ?(tag, tensor, step, metadata, name)
#     798         )
#     799         with ops.control_dependencies([write_summary_op]):
#     800           return constant_op.constant(True)
#     801
# --> 802     op = smart_cond.smart_cond(
#     803         should_record_summaries(), record, _nothing, name="summary_cond")
#     804     if not context.executing_eagerly():
#     805       ops.add_to_collection(ops.GraphKeys._SUMMARY_COLLECTION, op)  # pylint: disable=protected-access
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/framework/smart_cond.py in ?(pred, true_fn, false_fn, name)
#      49
#      50   pred_value = smart_constant_value(pred)
#      51   if pred_value is not None:
#      52     if pred_value:
# ---> 53       return true_fn()
#      54     else:
#      55       return false_fn()
#      56   else:
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/summary_ops_v2.py in ?()
#     778                          "tf.summary.experimental.set_step()")
#     779
#     780       # Note the identity to move the tensor to the CPU.
#     781       with ops.device("cpu:0"):
# --> 782         summary_tensor = tensor() if callable(tensor) else array_ops.identity(
#     783             tensor)
#     784         # For DTensor, the device scope above doesn't work, we need to
#     785         # explicitly copy the resource tensor to host mesh, which is a cpu
#
# ~/.local/lib/python3.10/site-packages/tensorboard/util/lazy_tensor_creator.py in ?(self)
#      62                         "Cannot use LazyTensorCreator with reentrant callable"
#      63                     )
#      64                 elif self._tensor is None:
#      65                     self._tensor = _CALL_IN_PROGRESS_SENTINEL
# ---> 66                     self._tensor = self._tensor_callable()
#      67         return self._tensor
#
# ~/.local/lib/python3.10/site-packages/tensorboard/plugins/histogram/summary_v2.py in ?()
#     192         @lazy_tensor_creator.LazyTensorCreator
#     193         def lazy_tensor():
# --> 194             return _buckets(data, buckets)
#
# ~/.local/lib/python3.10/site-packages/tensorboard/plugins/histogram/summary_v2.py in ?(data, bucket_count)
#     289             return tf.cond(
#     290                 has_single_value, when_single_value, when_multiple_values
#     291             )
#     292
# --> 293         return tf.cond(is_empty, when_empty, when_nonempty)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, name)
#     339   >>> r.numpy()
#     340   14
#     341
#     342   """
# --> 343   return cond(pred, true_fn=true_fn, false_fn=false_fn, strict=True, name=name)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py in ?(*args, **kwargs)
#     584                 _call_location(), decorator_utils.get_qualified_name(func),
#     585                 func.__module__, arg_name,
#     586                 'in a future version' if date is None else ('after %s' % date),
#     587                 instructions)
# --> 588       return func(*args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, strict, name, fn1, fn2)
#     138   if not callable(false_fn):
#     139     raise TypeError("'false_fn' must be callable.")
#     140
#     141   if context.executing_eagerly():
# --> 142     return _eager_cond_implementation(pred, true_fn, false_fn, strict, name)
#     143
#     144   # Always enable control flow v2 if building a function, regardless of toggle.
#     145   if util.EnableControlFlowV2(ops.get_default_graph()):
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, strict, name)
#     383     with ops.name_scope(name, "cond", [pred]):
#     384       if pred_constant_value:
#     385         result = true_fn()
#     386       else:
# --> 387         result = false_fn()
#     388       if not strict:
#     389         result = _UnpackIfSingleton(result)
#     390       return result
#
# ~/.local/lib/python3.10/site-packages/tensorboard/plugins/histogram/summary_v2.py in ?()
#     285                     dtype=tf.float64,
#     286                 )
#     287                 return tf.transpose(a=tf.stack([edges, edges, bucket_counts]))
#     288
# --> 289             return tf.cond(
#     290                 has_single_value, when_single_value, when_multiple_values
#     291             )
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, name)
#     339   >>> r.numpy()
#     340   14
#     341
#     342   """
# --> 343   return cond(pred, true_fn=true_fn, false_fn=false_fn, strict=True, name=name)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py in ?(*args, **kwargs)
#     584                 _call_location(), decorator_utils.get_qualified_name(func),
#     585                 func.__module__, arg_name,
#     586                 'in a future version' if date is None else ('after %s' % date),
#     587                 instructions)
# --> 588       return func(*args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, strict, name, fn1, fn2)
#     138   if not callable(false_fn):
#     139     raise TypeError("'false_fn' must be callable.")
#     140
#     141   if context.executing_eagerly():
# --> 142     return _eager_cond_implementation(pred, true_fn, false_fn, strict, name)
#     143
#     144   # Always enable control flow v2 if building a function, regardless of toggle.
#     145   if util.EnableControlFlowV2(ops.get_default_graph()):
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, strict, name)
#     383     with ops.name_scope(name, "cond", [pred]):
#     384       if pred_constant_value:
#     385         result = true_fn()
#     386       else:
# --> 387         result = false_fn()
#     388       if not strict:
#     389         result = _UnpackIfSingleton(result)
#     390       return result
#
# ~/.local/lib/python3.10/site-packages/tensorboard/plugins/histogram/summary_v2.py in ?()
#     248                 """When input data contains multiple values."""
#     249                 bucket_width = range_ / tf.cast(bucket_count, tf.float64)
#     250                 offsets = data - min_
#     251                 bucket_indices = tf.cast(
# --> 252                     tf.floor(offsets / bucket_width), dtype=tf.int32
#     253                 )
#     254                 clamped_indices = tf.minimum(bucket_indices, bucket_count - 1)
#     255                 # Use float64 instead of float32 to avoid accumulating floating point error
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py in ?(x, y)
#    1475         # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1476         #   r_binary_op_wrapper use different force_same_dtype values.
#    1477         x, y = maybe_promote_tensors(x, y)
#    1478         return func(x, y, name=name)
# -> 1479       except (TypeError, ValueError) as e:
#    1480         # Even if dispatching the op failed, the RHS may be a tensor aware
#    1481         # object that can implement the operator with knowledge of itself
#    1482         # and the tensor.
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py in ?(x, y, name)
#    1657
#    1658   Raises:
#    1659     TypeError: If `x` and `y` have different dtypes.
#    1660   """
# -> 1661   return _truediv_python3(x, y, name)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/weak_tensor_ops.py in ?(*args, **kwargs)
#     140   def wrapper(*args, **kwargs):
#     141     if not ops.is_auto_dtype_conversion_enabled():
# --> 142       return op(*args, **kwargs)
#     143     bound_arguments = signature.bind(*args, **kwargs)
#     144     bound_arguments.apply_defaults()
#     145     bound_kwargs = bound_arguments.arguments
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py in ?(x, y, name)
#    1595           f"of {{{', '.join([repr(x) for x in _TRUEDIV_TABLE.keys()])}}}.")
#    1596     if dtype is not None:
#    1597       x = cast(x, dtype)
#    1598       y = cast(y, dtype)
# -> 1599     return gen_math_ops.real_div(x, y, name=name)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/weak_tensor_ops.py in ?(*args, **kwargs)
#     140   def wrapper(*args, **kwargs):
#     141     if not ops.is_auto_dtype_conversion_enabled():
# --> 142       return op(*args, **kwargs)
#     143     bound_arguments = signature.bind(*args, **kwargs)
#     144     bound_arguments.apply_defaults()
#     145     bound_kwargs = bound_arguments.arguments
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/gen_math_ops.py in ?(x, y, name)
#    8090         _ctx, "RealDiv", name, x, y)
#    8091       return _result
#    8092     except _core._NotOkStatusException as e:
#    8093       _ops.raise_from_not_ok_status(e, name)
# -> 8094     except _core._FallbackException:
#    8095       pass
#    8096     try:
#    8097       _result = _dispatcher_for_real_div(
#
# KeyboardInterrupt:

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
